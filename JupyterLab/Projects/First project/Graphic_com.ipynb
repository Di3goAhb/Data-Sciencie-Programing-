# %%
import numpy as np
import matplotlib.pyplot as plt
Size = [10,100,1000,10000,100000,1000000,10000000,100000000]
mergesort_time = [0.0023345947265625, 0.0012028217315673828, 0.023589134216308594, 0.23186326026916504, 2.553248882293701, 28.919026136398315, 337.1712701320648, 3756.9321849818902]
numpysort_time = [0.0011069159991166089, 0.0006396700009645429, 0.00034126999889849685, 0.000819487999251578, 0.007069091996527277, 0.07538596200174652, 0.6727874110001721, 7.900679432998004]
quicksort_time = [0.00064, 0.00070, 0.01007, 0.11922, 1.11365, 13.87919, 156.23403, 1763.92157]
plt.plot(Size,mergesort_time,label='Mergesort')
plt.plot(Size,quicksort_time,label='Quicksort')
plt.plot(Size,numpysort_time,label='Numpysort')
plt.xlabel("Size")
plt.ylabel("Time Complexity")
plt.legend()
plt.show()
