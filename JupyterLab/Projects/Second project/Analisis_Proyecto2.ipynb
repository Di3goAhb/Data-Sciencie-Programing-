# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students=pd.read_csv('StudentsPerformance2.csv')
students
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
 x=(students.math_score+students.reading_score+students.writing_score)/3
students2=students
students2['mean']=x
students2
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
#Promedio del grupo A

# %%
mean = print((students2[students2['race_ethnicity'] =='group A']['mean']>=80).value_counts())
mean = print((students2[students2['race_ethnicity'] =='group A']['mean']<=60).value_counts())
# Out:
# False    78
# True     11
# Name: mean, dtype: int64
# False    49
# True     40
# Name: mean, dtype: int64

# %%
etiquetas=['Aprobados (11)','Reprobados(40)','Aprobación minima(38)']

x = np.array([11,40,38])
separar = (0, 0.1, 0)
colores = ('lightcyan','steelblue', 'skyblue' )
plt.rcParams['font.weight']='bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio general grupo A (89)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio general grupo A (89)')

# %%
mean = print((students2[students2['race_ethnicity'] =='group A']['writing_score']>=80).value_counts())
mean = print((students2[students2['race_ethnicity'] =='group A']['writing_score']<=60).value_counts())
# Out:
# False    74
# True     15
# Name: writing_score, dtype: int64
# False    50
# True     39
# Name: writing_score, dtype: int64

# %%
etiquetas=['Aprobados(15)','Reprobados(37)','Aprobación minima(37)']
x = np.array([15,37,37])
separar = (0, 0.1, 0)
colores = ('lightcyan','steelblue', 'skyblue' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Writing grupo A (89)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Writing grupo A (89)')

# %%
mean = print((students2[students2['race_ethnicity'] =='group A']['reading_score']>=80).value_counts())
mean = print((students2[students2['race_ethnicity'] =='group A']['reading_score']<=60).value_counts())
# Out:
# False    71
# True     18
# Name: reading_score, dtype: int64
# False    51
# True     38
# Name: reading_score, dtype: int64

# %%
etiquetas=['Aprobados(18)','Reprobados(42)','Aprobación minima(36)']
x = np.array([18,42,36])
separar = (0, 0.1, 0)
colores = ('lightcyan','steelblue', 'skyblue' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Reading grupo A (89)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Reading grupo A (89)')

# %%
etiquetas=['Aprobados(9)','Reprobados(42)','Aprobación minima(38)']
x = np.array([9,42,38])
separar = (0, 0.1, 0)
colores = ('lightcyan','steelblue', 'skyblue' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Matematicas grupo A (89)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Matematicas grupo A (89)')

# %%
mean = print((students2[students2['race_ethnicity'] =='group A']['math_score']>=60).value_counts())
# Out:
# True     47
# False    42
# Name: math_score, dtype: int64

# %%
#Promedio del grupo B

# %%
print((students2[students2['race_ethnicity'] =='group B']['mean']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group B']['mean']<=60).value_counts())
# Out:
# False    155
# True      35
# Name: mean, dtype: int64
# False    127
# True      63
# Name: mean, dtype: int64

# %%
etiquetas=['Aprobados(35)','Reprobados(59)','Aprobación minima(96)']
x = np.array([35,59,96])
separar = (0, 0.1, 0)
colores = ('wheat','chocolate', 'orange' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio General grupo B (190)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio General grupo B (190)')

# %%
print((students2[students2['race_ethnicity'] =='group B']['writing_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group B']['writing_score']<=60).value_counts())
# Out:
# False    152
# True      38
# Name: writing_score, dtype: int64
# False    121
# True      69
# Name: writing_score, dtype: int64

# %%
etiquetas=['Aprobados(38)','Reprobados(61)','Aprobación minima(91)']
x = np.array([38,61,91])
separar = (0, 0.1, 0)
colores = ('wheat','chocolate', 'orange' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Writing grupo B (190)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Writing grupo B (190)')

# %%
print((students2[students2['race_ethnicity'] =='group B']['reading_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group B']['reading_score']<=60).value_counts())
# Out:
# False    142
# True      48
# Name: reading_score, dtype: int64
# False    131
# True      59
# Name: reading_score, dtype: int64

# %%
etiquetas=['Aprobados(48)','Reprobados(55)','Aprobación minima(87)']
x = np.array([48,55,87])
separar = (0, 0.1, 0)
colores = ('wheat','chocolate', 'orange' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Reading grupo B (190)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Reading grupo B (190)')

# %%
print((students2[students2['race_ethnicity'] =='group B']['math_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group B']['math_score']<=60).value_counts())
# Out:
# False    161
# True      29
# Name: math_score, dtype: int64
# False    112
# True      78
# Name: math_score, dtype: int64

# %%
etiquetas=['Aprobados(29)','Reprobados(71)','Aprobación minima(90)']
x = np.array([29,71,100])
separar = (0, 0.1, 0)
colores = ('wheat','chocolate', 'orange' )
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Matematicas grupo B (190)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Matematicas grupo B (190)')

# %%
print((students2[students2['race_ethnicity'] =='group B']['math_score']>=80).value_counts())
# Out:
# False    161
# True      29
# Name: math_score, dtype: int64

# %%
#Promedio grupo C

# %%
print((students2[students2['race_ethnicity'] =='group C']['mean']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group C']['mean']<=60).value_counts())
# Out:
# False    264
# True      55
# Name: mean, dtype: int64
# False    218
# True     101
# Name: mean, dtype: int64

# %%
etiquetas=['Aprobados(55)','Reprobados(97)','Aprobación minima(167)']
x = np.array([55,97,167])
separar = (0, 0.1, 0)
colores = ('palegreen','seagreen', 'limegreen')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio general grupo C (319)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio general grupo C (319)')

# %%
print((students2[students2['race_ethnicity'] =='group C']['writing_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group C']['writing_score']<=60).value_counts())
# Out:
# False    244
# True      75
# Name: writing_score, dtype: int64
# False    221
# True      98
# Name: writing_score, dtype: int64

# %%
etiquetas=['Aprobados(75)','Reprobados(94)','Aprobación minima(150)']
x = np.array([75,94,150])
separar = (0, 0.1, 0)
colores = ('palegreen','seagreen', 'limegreen')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio writing grupo C (319)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio writing grupo C (319)')

# %%
print((students2[students2['race_ethnicity'] =='group C']['reading_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group C']['reading_score']<=60).value_counts())
# Out:
# False    246
# True      73
# Name: reading_score, dtype: int64
# False    236
# True      83
# Name: reading_score, dtype: int64

# %%
etiquetas=['Aprobados(73)','Reprobados(75)','Aprobación minima(171)']
x = np.array([75,94,150])
separar = (0, 0.1, 0)
colores = ('palegreen','seagreen', 'limegreen')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Reading grupo C (319)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Reading grupo C (319)')

# %%
print((students2[students2['race_ethnicity'] =='group C']['math_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group C']['math_score']<=60).value_counts())
# Out:
# False    270
# True      49
# Name: math_score, dtype: int64
# False    201
# True     118
# Name: math_score, dtype: int64

# %%
etiquetas=['Aprobados(49)','Reprobados(113)','Aprobación minima(157)']
x = np.array([49,113,157])
separar = (0, 0.1, 0)
colores = ('palegreen','seagreen', 'limegreen')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Matematicas grupo C (319)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Matematicas grupo C (319)')

# %%
#Promedio grupo D

# %%
print((students2[students2['race_ethnicity'] =='group D']['mean']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group D']['mean']<=60).value_counts())
# Out:
# False    209
# True      53
# Name: mean, dtype: int64
# False    197
# True      65
# Name: mean, dtype: int64

# %%
etiquetas=['Aprobados(53)','Reprobados(65)','Aprobación minima(144)']
x = np.array([53,65,144])
separar = (0, 0.1, 0)
colores = ('red','darkred', 'brown')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio general grupo D (262)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio general grupo D (262)')

# %%
print((students2[students2['race_ethnicity'] =='group D']['writing_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group D']['writing_score']<=60).value_counts())
# Out:
# False    195
# True      67
# Name: writing_score, dtype: int64
# False    198
# True      64
# Name: writing_score, dtype: int64

# %%
etiquetas=['Aprobados(67)','Reprobados(59)','Aprobación minima(136)']
x = np.array([67,59,136])
separar = (0, 0.1, 0)
colores = ('red','darkred', 'brown')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio writing grupo D (262)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio writing grupo D (262)')

# %%
print((students2[students2['race_ethnicity'] =='group D']['reading_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group D']['reading_score']<=60).value_counts())
# Out:
# False    199
# True      63
# Name: reading_score, dtype: int64
# False    196
# True      66
# Name: reading_score, dtype: int64

# %%
etiquetas=['Aprobados(63)','Reprobados(62)','Aprobación minima(137)']
x = np.array([63,62,137])
separar = (0, 0.1, 0)
colores = ('red','darkred', 'brown')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Reading grupo D (262)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Reading grupo D (262)')

# %%
print((students2[students2['race_ethnicity'] =='group D']['math_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group D']['math_score']<=60).value_counts())
# Out:
# False    211
# True      51
# Name: math_score, dtype: int64
# False    186
# True      76
# Name: math_score, dtype: int64

# %%
etiquetas=['Aprobados(41)','Reprobados(76)','Aprobación minima(145)']
x = np.array([41,76,145])
separar = (0, 0.1, 0)
colores = ('indianred','brown', 'red')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Matematicas grupo D (262)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Matematicas grupo D (262)')

# %%
#Promedio grupo E

# %%
print((students2[students2['race_ethnicity'] =='group E']['mean']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group E']['mean']<=60).value_counts())
# Out:
# False    96
# True     44
# Name: mean, dtype: int64
# False    116
# True      24
# Name: mean, dtype: int64

# %%
etiquetas=['Aprobados(44)','Reprobados(24)','Aprobación minima(72)']
x = np.array([44,24,72])
separar = (0, 0.1, 0)
colores = ('plum','darkviolet', 'mediumorchid')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio general grupo E (140)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio general grupo E (140)')

# %%
print((students2[students2['race_ethnicity'] =='group E']['writing_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group E']['writing_score']<=60).value_counts())
# Out:
# False    100
# True      40
# Name: writing_score, dtype: int64
# False    109
# True      31
# Name: writing_score, dtype: int64

# %%
etiquetas=['Aprobados(40)','Reprobados(30)','Aprobación minima(70)']
x = np.array([40,30,70])
separar = (0, 0.1, 0)
colores = ('plum','darkviolet', 'mediumorchid')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Writing grupo E (140)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Writing grupo E (140)')

# %%
print((students2[students2['race_ethnicity'] =='group E']['reading_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group E']['reading_score']<=60).value_counts())
# Out:
# False    93
# True     47
# Name: reading_score, dtype: int64
# False    111
# True      29
# Name: reading_score, dtype: int64

# %%
etiquetas=['Aprobados(47)','Reprobados(27)','Aprobación minima(66)']
x = np.array([44,27,66])
separar = (0, 0.1, 0)
colores = ('plum','darkviolet', 'mediumorchid')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Writing grupo E (140)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Writing grupo E (140)')

# %%
print((students2[students2['race_ethnicity'] =='group E']['math_score']>=80).value_counts())
print((students2[students2['race_ethnicity'] =='group E']['math_score']<=60).value_counts())
# Out:
# False    85
# True     55
# Name: math_score, dtype: int64
# False    115
# True      25
# Name: math_score, dtype: int64

# %%
etiquetas=['Aprobados(55)','Reprobados(25)','Aprobación minima(60)']
x = np.array([55,25,60])
separar = (0, 0.1, 0)
colores = ('plum','darkviolet', 'mediumorchid')
plt.rcParams['font.weight'] = 'bold'
plt.pie(x, labels=etiquetas, explode=separar, autopct='%1.2f%%', shadow=True, colors = colores)
plt.title('Promedio Matematicas grupo E (140)', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Promedio Matematicas grupo E (140)')

# %%
pen = students.value_counts('race_ethnicity')
pen
# Out:
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# dtype: int64

# %%
an = print((students2[students2['race_ethnicity'] =='group E']['mean']>=60).value_counts())
an
# Out:
# True     116
# False     24
# Name: mean, dtype: int64

# %%
x = ['Grupo A\n 89', 'Grupo B\n190', 'Grupo C\n319', 'Grupo D\n262', 'Grupo E\n140']
y = [89, 190, 319, 262, 140]
bars = plt.bar(x,y)
bars[0].set_color('skyblue')
bars[1].set_color('limegreen')
bars[2].set_color('orange')
bars[3].set_color('brown')
bars[4].set_color('plum')
plt.title('Alumnos totales', fontweight='bold')
plt.show()

x = ['Grupo A\n 40', 'Grupo B\n59', 'Grupo C\n97', 'Grupo D\n65', 'Grupo E\n24']
y = [40, 59, 97, 65, 24]
bars = plt.bar(x,y)
bars[0].set_color('skyblue')
bars[1].set_color('limegreen')
bars[2].set_color('orange')
bars[3].set_color('brown')
bars[4].set_color('plum')
plt.title('Alumnos Reprobados', fontweight='bold')
plt.show()

# %%
x = ['A', 'B', 'C', 'D', 'E']
y1 = [89, 190, 319, 262, 140]
y2 = [40, 59, 97, 65, 24]


plt.figure(figsize=(10, 6))
plt.bar(x, y1, label='Alumnos totales',)
plt.bar(x, y2, label='Alumnos\nreprobados')
for i, v in enumerate(y1):
    plt.text(i, v + 10, "{:.1f}%".format((y2[i] / v) * 100), ha='center')

plt.title('Alumnos', fontweight='bold')
plt.xlabel('Etnias por grupo')
plt.ylabel('Cantidad')
plt.legend()


plt.show()

# %%
students.value_counts('gender')
# Out:
# gender
# female    518
# male      482
# dtype: int64

# %%
x = ['Female\n 518', 'Male\n 482']
y = [518,482]
bars = plt.bar(x,y)
bars[0].set_color('skyblue')
bars[1].set_color('limegreen')
plt.title('Cantidad Mujeres y Hombres', fontweight='bold')
plt.show()

# %%
students.value_counts('parental_level_of_education')
# Out:
# parental_level_of_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# dtype: int64

# %%
plt.figure(figsize=(16, 10))
ax = sns.countplot(data=students, x='race_ethnicity', hue='parental_level_of_education')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center") plt.show()

# %%
students_group_b = students[students['race_ethnicity'] == 'group A']

plt.figure(figsize=(16,10))
ax = sns.countplot(data=students_group_b, x='parental_level_of_education', palette='Blues')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students_group_b))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center")

plt.title('Parental Level of Education for Group A Students')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')

plt.show()

# %%
students_group_b = students[students['race_ethnicity'] == 'group B']

plt.figure(figsize=(16,10))
ax = sns.countplot(data=students_group_b, x='parental_level_of_education', palette='Blues')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students_group_b))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center")

plt.title('Parental Level of Education for Group B Students')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')

plt.show()

# %%
students_group_b = students[students['race_ethnicity'] == 'group C']

plt.figure(figsize=(16,10))
ax = sns.countplot(data=students_group_b, x='parental_level_of_education', palette='Blues')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students_group_b))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center")

plt.title('Parental Level of Education for Group C Students')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')

plt.show()

# %%
students_group_b = students[students['race_ethnicity'] == 'group D']

plt.figure(figsize=(16,10))
ax = sns.countplot(data=students_group_b, x='parental_level_of_education', palette='Blues')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students_group_b))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center")

plt.title('Parental Level of Education for Group D Students')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')

plt.show()

# %%
students_group_b = students[students['race_ethnicity'] == 'group E']

plt.figure(figsize=(16,10))
ax = sns.countplot(data=students_group_b, x='parental_level_of_education', palette='Blues')

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / len(students_group_b))
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.text(x, y, percentage, ha="center")

plt.title('Parental Level of Education for Group E Students')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(16, 10))
ax = sns.countplot(data=students, x='race_ethnicity', hue='gender')

# %%
#APROBADOS Y REPROBADOS POR GENERO

# %%
mean1 = (students2[(students2['gender'] =='female') & (students2['race_ethnicity'] == 'group A')]['mean']<=60).value_counts()
mean1
# Out:
# False    21
# True     15
# Name: mean, dtype: int64

# %%
mean2 = (students2[(students2['gender'] =='male') & (students2['race_ethnicity'] == 'group A')]['mean']<=60).value_counts()
mean2
# Out:
# False    28
# True     25
# Name: mean, dtype: int64

# %%
labels0=['Aprobados', 'Reprobados']
#plot 1
x = np.array([21,15])
plt.subplot(1,2,1)
plt.pie(x, labels=labels0, autopct='%1.1f%%')
plt.title('female')
#plot 2
y = np.array([28,25])
plt.subplot(1,2,2)
plt.pie(y,labels=labels0, autopct='%1.1f%%')
plt.title('male')
plt.suptitle('APR/REP Group A')
plt.show()

# %%
mean3 = (students2[(students2['gender'] =='female') & (students2['race_ethnicity'] == 'group B')]['mean']<=60).value_counts()
mean3
# Out:
# False    79
# True     25
# Name: mean, dtype: int64

# %%
mean4 = (students2[(students2['gender'] =='male') & (students2['race_ethnicity'] == 'group B')]['mean']<=60).value_counts()
mean4
# Out:
# False    48
# True     38
# Name: mean, dtype: int64

# %%
labels0=['Aprobados', 'Reprobados']
#plot 1
x = np.array([79,25])
plt.subplot(1,2,1)
plt.pie(x, labels=labels0, autopct='%1.1f%%')
plt.title('female')
#plot 2
y = np.array([48,38])
plt.subplot(1,2,2)
plt.pie(y,labels=labels0, autopct='%1.1f%%')
plt.title('male')
plt.suptitle('APR/REP Group B')
plt.show()

# %%
mean5 = (students2[(students2['gender'] =='female') & (students2['race_ethnicity'] == 'group C')]['mean']<=60).value_counts()
mean5
# Out:
# False    132
# True      48
# Name: mean, dtype: int64

# %%
mean6 = (students2[(students2['gender'] =='male') & (students2['race_ethnicity'] == 'group C')]['mean']<=60).value_counts()
mean6
# Out:
# False    86
# True     53
# Name: mean, dtype: int64

# %%
labels0=['Aprobados', 'Reprobados']
#plot 1
x = np.array([132,48])
plt.subplot(1,2,1)
plt.pie(x, labels=labels0, autopct='%1.1f%%')
plt.title('female')
#plot 2
y = np.array([86,53])
plt.subplot(1,2,2)
plt.pie(y,labels=labels0, autopct='%1.1f%%')
plt.title('male')
plt.suptitle('APR/REP Group C')
plt.show()

# %%
mean7 = (students2[(students2['gender'] =='female') & (students2['race_ethnicity'] == 'group D')]['mean']<=60).value_counts()
mean7
# Out:
# False    100
# True      29
# Name: mean, dtype: int64

# %%
mean8 = (students2[(students2['gender'] =='male') & (students2['race_ethnicity'] == 'group D')]['mean']<=60).value_counts()
mean8
# Out:
# False    97
# True     36
# Name: mean, dtype: int64

# %%
labels0=['Aprobados', 'Reprobados']
#plot 1
x = np.array([100,29])
plt.subplot(1,2,1)
plt.pie(x, labels=labels0, autopct='%1.1f%%')
plt.title('female')
#plot 2
y = np.array([97,36])
plt.subplot(1,2,2)
plt.pie(y,labels=labels0, autopct='%1.1f%%')
plt.title('male')
plt.suptitle('APR/REP Group D')
plt.show()

# %%
mean9 = (students2[(students2['gender'] =='female') & (students2['race_ethnicity'] == 'group E')]['mean']<=60).value_counts()
mean9
# Out:
# False    58
# True     11
# Name: mean, dtype: int64

# %%
mean10 = (students2[(students2['gender'] =='male') & (students2['race_ethnicity'] == 'group E')]['mean']<=60).value_counts()
mean10
# Out:
# False    58
# True     13
# Name: mean, dtype: int64

# %%
labels0=['Aprobados', 'Reprobados']
#plot 1
x = np.array([58,11])
plt.subplot(1,2,1)
plt.pie(x, labels=labels0, autopct='%1.1f%%')
plt.title('female')
#plot 2
y = np.array([58,13])
plt.subplot(1,2,2)
plt.pie(y,labels=labels0, autopct='%1.1f%%')
plt.title('male')
plt.suptitle('APR/REP Group E')
plt.show()
